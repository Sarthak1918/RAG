# %% [markdown]
# ### RAG Pipelines - Data Ingestion to Vector DB Pipeline

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader,PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path
# Out:
# /var/folders/ky/rqm80vpj36g9jwk1jyhs6dg40000gn/T/ipykernel_72960/2865240289.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyMuPDFLoader,PyPDFLoader

# %%
### Read all the pdfs inside the directory

def process_all_pdfs(directory):
    all_documents = []
    pdf_directory = Path(directory)
    
    pdf_files = list(pdf_directory.glob("**/*.pdf")) ##Paths
    print("pdf files",pdf_files)
    print(f"Found {len(pdf_files)} PDFs to process")

    for pdf in pdf_files:
        print(f"\nProcessing: {pdf.name}")

    # Now load each and every pdf and add more info in metadata and save in all_documents
        try:
            loader = PyMuPDFLoader(str(pdf))
            documents = loader.load() ## this is pages which is converted to Document structure

            for doc in documents:
                doc.metadata['source_file'] = pdf.name
                doc.metadata['type'] = 'pdf'
            all_documents.extend(documents)
            print(f"✅ Processed {len(documents)}")
        except Exception as e:
            print("Error occured: ",e)
    print(f"Total Documents loaded: {len(all_documents)}")
    return all_documents

all_pdf_documents = process_all_pdfs("../data")
# Out:
# pdf files [PosixPath('../data/pdfs/02_Embeddings.pdf'), PosixPath('../data/pdfs/03_Object_Detection.pdf'), PosixPath('../data/pdfs/04_Region_Proposals.pdf'), PosixPath('../data/pdfs/01_Attention_Mechanism.pdf')]
# Found 4 PDFs to process
#
# Processing: 02_Embeddings.pdf
# ✅ Processed 2
#
# Processing: 03_Object_Detection.pdf
# ✅ Processed 2
#
# Processing: 04_Region_Proposals.pdf
# ✅ Processed 2
#
# Processing: 01_Attention_Mechanism.pdf
# ✅ Processed 2
# Total Documents loaded: 8

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content="Turning Words, Sentences & Documents into Vectors\nRAG\nVector DB\nSemantic Search\nLangChain\nLLMs\nWhat Are Embeddings?\nAn embedding is a dense numerical vector that represents the meaning of text (or images, audio, code)\nin a high-dimensional space. Texts with similar meanings end up close together — this is what makes\nsemantic search possible. A typical embedding model outputs a vector of 768–3072 floating-point\nnumbers.\nWhere Do Embeddings Fit?\n•   Core AI / NLP — Embeddings are a foundational concept used everywhere in modern NLP.\n•   RAG (Retrieval-Augmented Generation) — THE central component. Documents are embedded\nat index time; queries are embedded at search time; nearest vectors are retrieved and fed to the\nLLM.\n•   LangChain — Has a full Embeddings abstraction (`OpenAIEmbeddings`,\n`HuggingFaceEmbeddings`, etc.) used in `VectorstoreRetriever`.\n•   Vector Databases — Chroma, Pinecone, Weaviate, Qdrant all store and search embeddings.\nHow Embeddings Are Created\nModern embedding models are transformer encoders trained with contrastive objectives (e.g.,\nSentence-BERT, OpenAI text-embedding-3). The [CLS] token output or mean-pooled layer is used as\nthe embedding vector.\nLangChain Example:\nfrom langchain_openai import OpenAIEmbeddings embedder =\nOpenAIEmbeddings(model='text-embedding-3-small') vec = embedder.embed_query('What is\nattention?') # → list[float]\nSimilarity Metrics\nMetric\nFormula\nBest For\nCosine Similarity\ncos(θ) = A·B / (|A||B|)\nMost NLP tasks; length-invariant\nDot Product\nA · B\nWhen vectors are normalized\nEuclidean Distance\n√Σ(AI-BI)²\nLow-dim spaces, less common in NLP\nRAG Pipeline — Embeddings Role"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 1, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content="Embeddings appear at two critical points in a RAG system:\n•   Indexing phase — Each document chunk is embedded and stored in a vector DB with its text and\nmetadata.\n•   Query phase — The user query is embedded using the same model; nearest-neighbor search\n(ANN) finds the top-k chunks.\n•   Reranking — A cross-encoder can rerank retrieved chunks for better precision before passing to\nthe LLM.\nKey Rule\nThe query and document embeddings MUST come from the same model.\nMixing models breaks similarity scores entirely.\nPopular Embedding Models (2024–2025)\n•   text-embedding-3-small / large — OpenAI, fast and high quality.\n•   all-MiniLM-L6-v2 — HuggingFace, free, great for local RAG.\n•   bge-m3 — BAAI, multilingual, best open-source option.\n•   voyage-3 — Anthropic's embedding partner, strong on retrieval benchmarks.\nAI Concept Series · Embeddings · Quick Reference Guide"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/03_Object_Detection.pdf', 'file_path': '../data/pdfs/03_Object_Detection.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '03_Object_Detection.pdf', 'type': 'pdf'}, page_content='Finding & Classifying Objects in Images\nComputer Vision\nDeep Learning\nCNN\nYOLO\nVision Transformers\nWhat Is Object Detection?\nObject detection is a computer vision task that simultaneously answers two questions about an image:\nWhat objects are present? (classification) and Where are they? (localization via bounding boxes). The\noutput is a set of (class, confidence, x, y, w, h) tuples.\nRelationship to RAG / LangChain / NLP\n•   Core AI / Computer Vision — Object detection is a CV task, not an NLP task. It is separate from\nRAG and LangChain.\n•   Multimodal RAG — In advanced pipelines, detected objects can be described as text and\nembedded into a vector store for visual Q&A.;\n•   LangChain Vision Chains — GPT-4o / Claude can be used inside a LangChain chain to describe\nimages; object detection can pre-process frames before the LLM receives them.\nTwo-Stage vs One-Stage Detectors\nApproach\nHow It Works\nExamples\nSpeed / Accuracy\nTwo-Stage\n(Proposal-based)\nRegion proposals → classification\nof each region (ROI Pooling)\nR-CNN, Fast R-CNN,\nFaster R-CNN\nSlower, higher accuracy\nOne-Stage\nDivide image into grid; predict boxes\nand classes in a single pass\nYOLO (v3–v10),\nSSD, RetinaNet\nFaster, real-time\nTransformer-based\nDetect objects as a set prediction\nproblem with cross-attention\nDETR, DINO,\nGrounding DINO\nFlexible, strong accuracy\nKey Concepts\n•   Bounding Box — Rectangle defined as (x_center, y_center, width, height) normalised to image\nsize.\n•   IoU (Intersection over Union) — Measures overlap between predicted and ground-truth boxes.\nIoU > 0.5 typically counts as a correct detection.\n•   NMS (Non-Maximum Suppression) — Post-processing step that removes duplicate boxes by\nkeeping the highest-confidence box and discarding overlapping ones.\n•   Anchor Boxes — Pre-defined box shapes the model predicts offsets from (used in YOLO, SSD).'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/03_Object_Detection.pdf', 'file_path': '../data/pdfs/03_Object_Detection.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 1, 'source_file': '03_Object_Detection.pdf', 'type': 'pdf'}, page_content="•   mAP (mean Average Precision) — Standard evaluation metric across classes and IoU\nthresholds.\nYOLO — The Dominant One-Stage Detector\nYou Only Look Once (YOLO) divides the image into an S×S grid. Each cell predicts B bounding boxes\nwith confidence scores and C class probabilities simultaneously — making it extremely fast (real-time\non GPU). YOLOv8 / YOLOv10 are the current standard for production use.\nQuick Start (YOLOv8):\nfrom ultralytics import YOLO model = YOLO('yolov8n.pt') # nano = fastest results =\nmodel('image.jpg') # predict results[0].show() # visualise boxes\nVision AI Today\nFoundation models like GPT-4o, Claude 3.5, and Gemini 1.5 can detect\nand describe objects in images without task-specific training, blurring the\nline between object detection and VLMs.\nAI Concept Series · Object Detection · Quick Reference Guide"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/04_Region_Proposals.pdf', 'file_path': '../data/pdfs/04_Region_Proposals.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '04_Region_Proposals.pdf', 'type': 'pdf'}, page_content='How Detectors Find Candidate Object Locations\nComputer Vision\nR-CNN\nRPN\nObject Detection\nAnchor Boxes\nWhat Is a Region Proposal?\nA region proposal (or region of interest, RoI) is a candidate bounding box that might contain an object.\nInstead of scanning every possible window in an image (brute force), proposal methods quickly\ngenerate a smaller set of high-likelihood candidate regions that a classifier then evaluates. This\ntwo-stage design dramatically improves both speed and accuracy compared to exhaustive sliding\nwindow search.\nRelationship to RAG / LangChain / NLP\n•   Pure Computer Vision concept — Region proposals are specific to object detection pipelines,\nnot related to NLP, RAG, or LangChain.\n•   Agentic AI vision tools — When building LLM agents with tool use for vision, an object detector\n(which uses proposals internally) can be a tool called by LangChain/LangGraph.\n•   Document parsing — Layout detection models (used to parse PDFs/invoices for RAG) use\nregion proposals to locate text blocks and tables.\nEvolution: From Selective Search to RPN\nMethod\nYear\nHow It Generates Proposals\nSpeed\nSliding Window\nPre-2014\nDense multi-scale window scan\nVery slow (millions of windows)\nSelective Search\n2013\nGroup similar pixels (colour, texture)\ninto hierarchical regions\n~2s/image (CPU)\nEdgeBoxes\n2014\nScore boxes by edge density inside them\n~0.2s/image\nRPN (Faster RCNN)\n2015\nFully conv net shares backbone with\ndetector; predicts anchors\n~10ms on GPU\nAnchor-Free\n2019+\nPredict center points (CenterNet, FCOS)\ninstead of anchors\nFastest\nRegion Proposal Network (RPN) — Deep Dive\nIntroduced in Faster R-CNN (Ren et al., 2015), the RPN is a small fully-convolutional network that slides\nover the shared feature map. At each spatial location it evaluates k anchor boxes (combinations of\nscales × aspect-ratios). For each anchor it outputs two things: an objectness score (object vs\nbackground) and four box-offset deltas.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/04_Region_Proposals.pdf', 'file_path': '../data/pdfs/04_Region_Proposals.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 1, 'source_file': '04_Region_Proposals.pdf', 'type': 'pdf'}, page_content='•   Anchors — Pre-defined reference boxes. Typical: 3 scales × 3 ratios = 9 anchors per location.\n•   Objectness score — Binary classifier: does this anchor overlap an object (IoU > 0.7 → positive)?\n•   Box regression — Predict (∆x, ∆y, ∆w, ∆h) offsets to refine the anchor into a tight proposal.\n•   NMS on proposals — Top-N proposals (e.g. 300) kept after NMS before the detection head.\nRoI Pooling & RoI Align\nAfter proposals are generated, each RoI must be mapped to a fixed-size feature map for the classifier\nhead. RoI Pooling (Fast R-CNN) does this with max-pool but introduces quantisation misalignment. RoI\nAlign (Mask R-CNN) fixes this with bilinear interpolation — critical for tasks like instance segmentation.\nModern Trend\nTransformer-based detectors (DETR and successors) eliminate region\nproposals entirely, instead treating detection as a direct set prediction\nproblem using cross-attention between query vectors and image features.\nThis simplifies the pipeline but requires more data/training.\nThe Full Faster R-CNN Pipeline\nBackbone (ResNet) → FPN → RPN → RoI Align → Detection Head → NMS → Output\n•   Backbone — CNN (e.g. ResNet-50) extracts feature maps from the image.\n•   FPN (Feature Pyramid Network) — Multi-scale feature maps for detecting small and large\nobjects.\n•   RPN — Generates ~2000 candidate proposals per image.\n•   RoI Align — Warps each proposal region to 7×7 feature grid.\n•   Detection Head — FC layers output final class + refined box coordinates.\nAI Concept Series · Region Proposals · Quick Reference Guide'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/01_Attention_Mechanism.pdf', 'file_path': '../data/pdfs/01_Attention_Mechanism.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '01_Attention_Mechanism.pdf', 'type': 'pdf'}, page_content='The Core Idea Behind Transformers & LLMs\nDeep Learning\nNLP\nLLMs\nTransformers\nRAG\nWhat Is Attention?\nAttention is a mechanism that lets a neural network focus on the most relevant parts of an input when\nproducing each output token. Instead of compressing an entire sequence into one fixed vector, attention\ndynamically assigns a weight to every input position — giving more influence to positions that matter for\nthe current step.\nWhere Does It Fit?\n•   Raw AI / Deep Learning — Attention is a fundamental DL building block, not specific to RAG or\nLangChain.\n•   Transformers (GPT, BERT, etc.) — Every modern LLM is built entirely on attention layers\n("Attention Is All You Need", Vaswani et al. 2017).\n•   RAG — The LLM inside a RAG pipeline uses attention internally to fuse retrieved chunks with the\nquery.\n•   LangChain — LangChain orchestrates LLMs; attention is what makes those LLMs understand\ncontext.\nHow Scaled Dot-Product Attention Works\nEach token is projected into three vectors: Query (Q), Key (K), and Value (V). The attention score\nbetween a query and all keys is computed, scaled, softmaxed, then used to weight the values:\nFormula:\nAttention(Q, K, V) = softmax( Q·KT / √dk ) · V\nd_k\nDimension of the key vectors. Dividing by √d_k prevents the dot products\nfrom growing too large and causing vanishing gradients in softmax.\nMulti-Head Attention\nInstead of one attention function, the model runs h parallel attention heads each learning different\nrelationships (syntax, coreference, semantics). Outputs are concatenated and projected:\nMultiHead(Q,K,V) = Concat(head_1, ..., head_h) · W_O\nTypes of Attention'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/01_Attention_Mechanism.pdf', 'file_path': '../data/pdfs/01_Attention_Mechanism.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 1, 'source_file': '01_Attention_Mechanism.pdf', 'type': 'pdf'}, page_content='Type\nDescription\nUsed In\nSelf-Attention\nEach token attends to all other tokens\nin the same sequence\nTransformer encoder/decoder\nCross-Attention\nQuery from one sequence, K/V from another\nDecoder attending to encoder\nCausal/Masked\nFuture tokens masked so model can\'t peek\nGPT-style autoregressive LLMs\nSparse Attention\nOnly attend to a subset to save memory\nLong documents (Longformer)\nWhy It Matters for You (LLMs & RAG)\n•   Understanding attention helps you write better prompts — place the most important context near\nthe query.\n•   In RAG, retrieved chunks compete for the model\'s attention; chunk quality and ordering directly\naffect output.\n•   Context window limits are attention limits — the model can only "attend" to tokens within its\nwindow.\n•   Fine-tuning, LoRA, and PEFT all modify how attention weights are updated.\nAI Concept Series · Attention Mechanism · Quick Reference Guide')]

# %%
## Text Splitting 

def split_documents(documents,chunk_size=300,chunk_overlap=50):
    """SPLIT DOCUMENTS INTO SMALLER CHUNKS FOR BETTER RAG PERFORMANCE"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n",""," ","\n"]
    )

    split_docs = text_splitter.split_documents(documents=documents)
    print(f"Split {len(documents)} no of documents into {len(split_docs)} chunks")


    if split_docs:
        print(f"\n Example chunk")
        print(f"split_docs : ",split_docs)
        print(f"Content: {split_docs[0].page_content[:200]}")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks = split_documents(all_pdf_documents)
# Out:
# Split 8 no of documents into 142 chunks
#
#  Example chunk
# split_docs :  [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content='Turning Words, Sentences & Documents into Vectors\nRAG\nVector DB\nSemantic Search\nLangChain\nLLMs\nWhat'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content='LangChain\nLLMs\nWhat Are Embeddings?\nAn embedding is a dense numerical vector that represents the mea'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content='t represents the meaning of text (or images, audio, code)\nin a high-dimensional space. Texts with si'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content='space. Texts with similar meanings end up close together — this is what makes\nsemantic search possib'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}, page_content='mantic search possible. A typical embedding model outputs a vector of 768–3072 floating-point\nnumber'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'typ ...
# Content: Turning Words, Sentences & Documents into Vectors
# RAG
# Vector DB
# Semantic Search
# LangChain
# LLMs
# What
# Metadata: {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-09T10:19:17+00:00', 'source': '../data/pdfs/02_Embeddings.pdf', 'file_path': '../data/pdfs/02_Embeddings.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-09T10:19:17+00:00', 'trapped': '', 'modDate': "D:20260609101917+00'00'", 'creationDate': "D:20260609101917+00'00'", 'page': 0, 'source_file': '02_Embeddings.pdf', 'type': 'pdf'}
