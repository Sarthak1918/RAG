# %% [markdown]
# ### Data Ingestion

# %%
###Document datastructure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is the main text content i am using to create RAG",
    metadata = {
        "source" :"example.txt",
        "author":"Sarthak Panda",
        "pages":1,
        "date_created":"09-06-2025"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'Sarthak Panda', 'pages': 1, 'date_created': '09-06-2025'}, page_content='This is the main text content i am using to create RAG')

# %%
import os

os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text = {
"../data/text_files/python_intro.txt":'''
    Python is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, automation, data analysis, artificial intelligence, scripting, and software development. Python follows a "write less, do more" philosophy, allowing developers to build applications quickly and efficiently.

    Key Features
    Easy-to-read and beginner-friendly syntax
    Cross-platform support (Windows, macOS, Linux)
    Large standard library and ecosystem
    Supports multiple programming paradigms (OOP, Functional, Procedural)
    Strong community support


    Common Use Cases
    Web Development (using frameworks like Django and Flask)
    Data Analysis (using Pandas and NumPy)
    Automation and Scripting
    Artificial Intelligence and Machine Learning
    API Development
    Data Engineering

    Python is often the first language recommended to beginners because it helps them focus on problem-solving rather than complex syntax.''',

"../data/text_files/machine_learning_intro.txt":""" 
    Machine Learning (ML) is a branch of Artificial Intelligence (AI) that enables computers to learn patterns from data and make predictions or decisions without being explicitly programmed for every scenario. Instead of writing rules manually, developers provide data, and the model learns the underlying relationships.

    Types of Machine Learning
    1. Supervised Learning

    The model learns from labeled data.

    Example:
    Predicting house prices based on size, location, and number of rooms.

    Algorithms:

    Linear Regression
    Decision Trees
    Random Forest
    Support Vector Machines
    2. Unsupervised Learning

    The model finds hidden patterns in unlabeled data.

    Example:
    Customer segmentation for marketing campaigns.

    Applications
    Recommendation Systems (Netflix, YouTube)
    Fraud Detection
    Chatbots and Virtual Assistants
    Image Recognition
    Medical Diagnosis
    Predictive Analytics

    Machine Learning powers many modern applications by transforming large amounts of data into actionable insights and intelligent predictions."""
}

for filepath,content in sample_text.items():
    with open(filepath,"w",encoding="utf-8") as file:
        file.write(content)
print("✅ Sample Text Files are created")
# Out:
# ✅ Sample Text Files are created

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()

document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\n    Python is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, automation, data analysis, artificial intelligence, scripting, and software development. Python follows a "write less, do more" philosophy, allowing developers to build applications quickly and efficiently.\n\n    Key Features\n    Easy-to-read and beginner-friendly syntax\n    Cross-platform support (Windows, macOS, Linux)\n    Large standard library and ecosystem\n    Supports multiple programming paradigms (OOP, Functional, Procedural)\n    Strong community support\n\n\n    Common Use Cases\n    Web Development (using frameworks like Django and Flask)\n    Data Analysis (using Pandas and NumPy)\n    Automation and Scripting\n    Artificial Intelligence and Machine Learning\n    API Development\n    Data Engineering\n\n    Python is often the first languag
# ...

# %%
### Directory Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ##Pattern
    loader_cls=TextLoader, ##Loader to use
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

documents = dir_loader.load()

documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\n    Python is a high-level, interpreted programming language known for its simple syntax and readability. It is widely used in web development, automation, data analysis, artificial intelligence, scripting, and software development. Python follows a "write less, do more" philosophy, allowing developers to build applications quickly and efficiently.\n\n    Key Features\n    Easy-to-read and beginner-friendly syntax\n    Cross-platform support (Windows, macOS, Linux)\n    Large standard library and ecosystem\n    Supports multiple programming paradigms (OOP, Functional, Procedural)\n    Strong community support\n\n\n    Common Use Cases\n    Web Development (using frameworks like Django and Flask)\n    Data Analysis (using Pandas and NumPy)\n    Automation and Scripting\n    Artificial Intelligence and Machine Learning\n    API Development\n    Data Engineering\n\n    Python is often the first languag
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader


dir_loader = DirectoryLoader(
    "../data/pdfs",
    glob="**/*.pdf", ##Pattern
    loader_cls=PyMuPDFLoader, ##Loader to use
    show_progress=False
)

pdf_docs = dir_loader.load()
print(pdf_docs)
# Out:
# [Document(metadata={'producer': 'Prince 16 (www.princexml.com)', 'creator': '', 'creationdate': '', 'source': '../data/pdfs/sample2.pdf', 'file_path': '../data/pdfs/sample2.pdf', 'total_pages': 3, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='USENIX Example Paper\nPekka Nikander\nAalto University\nJane-Ellen Long\nUSENIX Association\nAbstract\nThis is an example for a USENIX paper, in the form\nof an HTML/CSS template. Being heavily self-ref-\nerential, this template illustrates the features in-\ncluded in this template. It is expected that the\nprospective authors using HTML/CSS would create\na new document based on this template, remove\nthe content, and start writing their paper.\nNote that in this template, you may have a mul-\nti-paragraph abstract. However, that it is not nec-\nessarily a good practice. Try to keep your abstract\nin one paragraph, and reme
# ...
